# %% [markdown]
# <a href="https://colab.research.google.com/github/dahee721/class2024/blob/main/5_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %%
import pandas as pd

a = pd.read_csv("weather.csv")
b = pd.DataFrame([{"Column1": "A", "Column2": 1000}, {"Column1": "B", "Column2": 300}])

# %%
from google.colab import drive
drive.mount('/content/drive')
a.to_csv('/content/drive/My Drive/product.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
wdf = pd.read_csv("/weather.csv")
wdf.loc[0, "Temperature"]
# Out:
# 22.2

# %%
#slicing - 범위 자르는거
#2~4까지 갖고오고 싶으면 1:4로 쓰기 -> list, numpy
#그러나 pandas에서는 2:4쓰기 -> pandas

wdf.loc[1:2, ["Temperature", "Humidity"]]
# Out:
#    Temperature  Humidity
# 1         20.0        50
# 2         18.3        45

# %%
a=[1,2,3,4,5]
a[1:4]
# Out:
# [2, 3, 4]

# %%
#데이터 추가하기 - pandas
wdf.loc[5] = { "Temperature": 19, "Humidity": 28, "City": "Seoul" }

wdf.loc[3:5, ["Temperature", "Humidity", "City"]]
# Out:
#    Temperature  Humidity     City
# 3         23.9        35  Houston
# 4         21.1        40  Phoenix
# 5         19.0        28    Seoul

# %%
#데이서 삭제하기
#np.mean(a, acis = 0) -> 특정 축에서 평균을 구하겠다

wdf = wdf.drop(5, axis=0)

# %%
wdf.drop("City", axis=1)

#wdf = wdf.drop("City", axis=1) 이라고 앞에 'wdf=' 안적어주면, 나중에 wdf 프린트해도 변해있지 않음. 함수마다 다른데, wdf는 그래야함
# Out:
#    Temperature  Humidity
# 0         22.2        30
# 1         20.0        50
# 2         18.3        45
# 3         23.9        35
# 4         21.1        40

# %%
print(wdf)
# Out:
#    Temperature  Humidity         City
# 0         22.2        30     New York
# 1         20.0        50  Los Angeles
# 2         18.3        45      Chicago
# 3         23.9        35      Houston
# 4         21.1        40      Phoenix

# %%
import numpy as np

c = np.array([1,2])
d = np.array([3,4])

c+d
# Out:
# array([4, 6])

# %%
wdf["Humidity"] = wdf["Humidity"] +2
wdf
# Out:
#    Temperature  Humidity         City
# 0         22.2        32     New York
# 1         20.0        52  Los Angeles
# 2         18.3        47      Chicago
# 3         23.9        37      Houston
# 4         21.1        42      Phoenix

# %%
wdf["Humidity"] > 40

# %% [markdown]
# ## Basics
#
# * DataFrame
#
# ```python
# import pandas as pd
#
# a = pd.read_csv("weather.csv")
# b = pd.DataFrame([{"Column1": "A", "Column2": 1000}, {"Column1": "B", "Column2": 300}])
# ```
#
# * Accessing Values
#
# ```python
# # Column
# b = a["Temperature"]
# d = a[["Humidity", "City"]]
#
# # Row
# e = a.loc[0]
# f = a.loc[1:2]
#
# # Specific value
# g = a.loc[0, "Temperature"]
# h = a.loc[1:2, ["Humidity", "City"]]
# ```
#
# * Adding Values
#
# ```python
# a.loc[5] = { "Temperature": 19, "Humidity": 28, "City": "Seoul" }
# ```
#
# * Deleting Values
#
# ```python
# # Column
# a = a.drop("Temperature", axis=1)
#
# # Row
# a = a.drop(5, axis=0)
# ```
#
# * Basic Operations
#
# ```python
# a.Quantity + 2
# a.Quantity > 60
# ```

# %%
pdf = pd.read_csv("/product.csv")

# %%
# 밑에 두 코드는 동일함
# pdf["Category"]
# pdf.Category

pdf.Category.value_counts()

# %%
pdf.groupby("Category").mean(numeric_only=True)

#밑에 거 복사할 때, 'a'가 아니라, 'pdf'써야 함
# Out:
#            Price   Quantity
# Category
# Fruit       0.80  55.000000
# Vegetable   0.85  61.666667

# %%
pdf.sort_values(by="Category")

# %%
pdf[pdf.Quantity >= 60]
# Out:
#     Category    Item  Price  Quantity
# 1      Fruit  Banana   0.65        60
# 2  Vegetable  Carrot   0.50        70
# 5  Vegetable  Carrot   0.55        75

# %% [markdown]
# ## Grouping
#
# * value_counts()
#
# ```python
# a.Category.value_counts()
# ```
#
# * groupby()
#
# ```python
# a.groupby("Category").mean(numeric_only=True)
# ```

# %% [markdown]
# ## Filtering & Sorting
#
# * Filtering
#
# ```python
# a[a.Quantity > 60]
# ```
#
# * Sorting
#
# ```python
# a.sort_values(by="Category")
# ```

# %% [markdown]
# ## Plotting
#
# * Line Plot
#
# ```python
# import matplotlib.pyplot as plt
#
# a.plot(x="Price", y="Quantity", kind="line")
# plt.show()
# ```
#
# * Scatter Plot
#
# ```python
# a.plot(x="Price", y="Quantity", kind="scatter")
# plt.show()
# ```
#
# * Bar Plot
#
# ```python
# a.plot(x="City", y="Humidity", kind="bar")
# plt.show()
# ```
#
# * Pie Chart
#
# ```python
# a = pd.DataFrame([{"Category": "A", "Sales": 1000},
#   {"Category": "B", "Sales": 300},
#   {"Category": "C", "Sales": 450},
#   {"Category": "D", "Sales": 100}])
#
# a.plot(y="Sales", kind="pie", labels=a.Category)
# plt.show()
# ```

# %%
#pie chart 시험범위x

# %%
import matplotlib.pyplot as plt

pdf.plot(x="Price", y="Quantity", kind="line")
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
